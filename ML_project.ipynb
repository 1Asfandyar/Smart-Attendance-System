# %% [markdown]
# <a href="https://colab.research.google.com/github/1Asfandyar/Smart-Attendance-System/blob/AI-model/ML_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Need to Install some Packages**
#
#
#
# *   deep face for face verification
# *   MTCNN for face recognition

# %%
# !pip install deepface
# !pip install mtcnn

# %% [markdown]
# **Using MTCNN, Recognizing Faces in the image**

# %%
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN


def draw_image_with_boxes(filename, result_list):
	
	data = pyplot.imread(filename)
	
	pyplot.imshow(data)
	
	ax = pyplot.gca()
	
	for result in result_list:
		
		x, y, width, height = result['box']
		
		rect = Rectangle((x, y), width, height, fill=False, color='red')
		
		ax.add_patch(rect)
	
	pyplot.show()

filename = 'pp.jpg'

pixels = pyplot.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_image_with_boxes(filename, faces)

# %% [markdown]
# **Using Deep face verify the faces**

# %%
from matplotlib import pyplot
from matplotlib.patches import Rectangle
from mtcnn.mtcnn import MTCNN
from deepface import DeepFace


def draw_image_with_boxes(filename, result_list):

  # for result in result_list:
  for i in range(0, len(result_list)):
    data = pyplot.imread(filename)
    x, y, width, height = result_list[i]['box']
    metrics = ["cosine", "euclidean", "euclidean_l2"]
    rect = Rectangle((x, y), width, height, fill=False, color='red')
    Count = 0
    for metric in metrics:
      result = DeepFace.verify(data[y-10:y+height+10, x-10:x+width+10, :],'Image1.jpg',  distance_metric = metric)
      if result['verified'] == True:
        Count += 1
    # print(Count)
    if Count == len(metrics):
      print('Abdullah is present in the image')
      pyplot.imshow(data)
      ax = pyplot.gca()
      ax.add_patch(rect)
      pyplot.show()

    
      # print(i,' = ' ,result['verified'])
      # print(result)
    # if(result['verified'] == True):
    #   print('Abdullah is present in the image')
    #   pyplot.imshow(data)
    #   ax = pyplot.gca()
    #   ax.add_patch(rect)
    #   pyplot.show()

    # else:
    #   pass



    # pyplot.imshow(data[y-10:y+height+10, x-10:x+width+10, :])


filename = 'pp.jpg'
pixels = pyplot.imread(filename)
detector = MTCNN()
faces = detector.detect_faces(pixels)
draw_image_with_boxes(filename, faces)
# Out:
# Abdullah is present in the image

# %% [markdown]
# **DeepFace  function to verify face exist or not**

# %%
Image = DeepFace.detectFace('Usama.jpeg')
pyplot.imshow(Image)
